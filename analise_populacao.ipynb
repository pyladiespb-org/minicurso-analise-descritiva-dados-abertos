# %% [markdown]
# # Análise da população brasileira
# by: Lorena Pereira
#
# ### Qual o perfil da população do nosso país? E do nosso estado?
#
# Com dados do censo de 2010, disponível pelo SIDRA [Sistema IBGE de Recuperação Automática](https://sidra.ibge.gov.br/home/pms/brasil)
# vamos extrair informações sobre características gerais da população como gênero, cor/raça, situação do domicílio, idade e unidade da federação.
#
# A partir desses dados será que a gente responder as perguntas anteriores?
#
# Fonte dos dados: https://sidra.ibge.gov.br/tabela/3175

# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Mas primeiro: Quem é Pandas e o que ele faz?
#
# Pandas é uma biblioteca open source que proporciona alta performace no tratamento e manipulação de estrutura de dados.
# Principais conceitos e funções:
# - Series
# - DataFrame - Conjunto de Series
# - Read - pd.read()
# - ...

# %%
populacao = pd.read_csv('data/populacao/populacao_genero_cor_2010.csv', delimiter=';', header=2)
populacao
# Out:
#                   Unidade da Federação  \
# 0                             Rondônia
# 1                             Rondônia
# 2                             Rondônia
# 3                             Rondônia
# 4                             Rondônia
# 5                             Rondônia
# 6                             Rondônia
# 7                             Rondônia
# 8                             Rondônia
# 9                             Rondônia
# 10                            Rondônia
# 11                            Rondônia
# 12                            Rondônia
# 13                            Rondônia
# 14                            Rondônia
# 15                            Rondônia
# 16                            Rondônia
# 17                            Rondônia
# 18                            Rondônia
# 19                            Rondônia
# 20                            Rondônia
# 21                            Rondônia
# 22                            Rondônia
# 23                            Rondônia
# 24                            Rondônia
# 25                            Rondônia
# 26                            Rondônia
# 27                            Rondônia
# 28                            Rondônia
# 29                            Rondônia
# ...                                ...
# 57654                 Distrito Federal
# 57655                 Distrito Federal
# 57656                 Distrito Federal
# 57657                 Distrito Federal
# 57658                 Distrito Federal
# 57659                 Distrito Federal
# 57660                 Distrito Federal
# 57661                 Distrito Federal
# 57662                 Distrito Federal
# 57663                 Distrito Federal
# 57664                 Distrito Federal
# 57665                 Distrito Federal
# 57666                 Distrito Federal
# 57667                 Distrito Federal
# 57668                 Distrito Federal
# 57669                 Distrito Federal
# 57670                 Distrito Federal
# 57671                 Distrito Federal
# 57672  Fonte: IBGE - Censo Demográfico
# 57673                            Notas
# 57674           1 - Dados do Universo.
# 57675                              NaN
# 57676                          Legenda
# 57677                          Símbolo
# 57678                                -
# 57679                                0
# 57680                                X
# 57681                               ..
# 57682                              ...
# 57683                A a Z\n(exceto X)
#
#                                                     Sexo             Idade  \
# 0                                                 Homens        0 a 4 anos
# 1                                                 Homens        0 a 4 anos
# 2                                                 Homens        0 a 4 anos
# 3                                                 Homens        0 a 4 anos
# 4                                                 Homens        0 a 4 anos
# 5                                                 Homens        0 a 4 anos
# 6                                                 Homens        0 a 4 anos
# 7                                                 Homens        0 a 4 anos
# 8                                                 Homens        0 a 4 anos
# 9                                                 Homens        0 a 4 anos
# 10                                                Homens        0 a 4 anos
# 11                                                Homens        0 a 4 anos
# 12                                                Homens        5 a 9 anos
# 13                                                Homens        5 a 9 anos
# 14                                                Homens        5 a 9 anos
# 15                                                Homens        5 a 9 anos
# 16                                                Homens        5 a 9 anos
# 17                                                Homens        5 a 9 anos
# 18                                                Homens        5 a 9 anos
# 19                                                Homens        5 a 9 anos
# 20                                                Homens        5 a 9 anos
# 21                                                Homens        5 a 9 anos
# 22                                                Homens        5 a 9 anos
# 23                                                Homens        5 a 9 anos
# 24                                                Homens      10 a 14 anos
# 25                                                Homens      10 a 14 anos
# 26                                                Homens      10 a 14 anos
# 27                                                Homens      10 a 14 anos
# 28                                                Homens      10 a 14 anos
# 29                                                Homens      10 a 14 anos
# ...                                                  ...               ...
# 57654                                           Mulheres           99 anos
# 57655                                           Mulheres           99 anos
# 57656                                           Mulheres           99 anos
# 57657                                           Mulheres           99 anos
# 57658                                           Mulheres           99 anos
# 57659                                           Mulheres           99 anos
# 57660                                           Mulheres  100 anos ou mais
# 57661                                           Mulheres  100 anos ou mais
# 57662                                           Mulheres  100 anos ou mais
# 57663                                           Mulheres  100 anos ou mais
# 57664                                           Mulheres  100 anos ou mais
# 57665                                           Mulheres  100 anos ou mais
# 57666                                           Mulheres  100 anos ou mais
# 57667                                           Mulheres  100 anos ou mais
# 57668                                           Mulheres  100 anos ou mais
# 57669                                           Mulheres  100 anos ou mais
# 57670                                           Mulheres  100 anos ou mais
# 57671                                           Mulheres  100 anos ou mais
# 57672                                                NaN               NaN
# 57673                                                NaN               NaN
# 57674                                                NaN               NaN
# 57675                                                NaN               NaN
# 57676                                                NaN               NaN
# 57677                                        Significado               NaN
# 57678  Zero absoluto, não resultante de um cálculo ou...               NaN
# 57679  Zero resultante de um cálculo ou arredondament...               NaN
# 57680  Valor inibido para não identificar o informant...               NaN
# 57681  Valor não se aplica.\nEx: Não se pode obter o ...               NaN
# 57682  Valor não disponível.\nEx: A produção de feijã...               NaN
# 57683  Significa uma faixa de valores. Varia em funçã...               NaN
#
#           Ano     Cor ou raça Situação do domicílio Unnamed: 6
# 0      2010.0          Branca                Urbana      18720
# 1      2010.0          Branca                 Rural       6024
# 2      2010.0           Preta                Urbana       1755
# 3      2010.0           Preta                 Rural        580
# 4      2010.0         Amarela                Urbana        643
# 5      2010.0         Amarela                 Rural        162
# 6      2010.0           Parda                Urbana      26827
# 7      2010.0           Parda                 Rural       9230
# 8      2010.0        Indígena                Urbana        116
# 9      2010.0        Indígena                 Rural        793
# 10     2010.0  Sem declaração                Urbana          4
# 11     2010.0  Sem declaração                 Rural          -
# 12     2010.0          Branca                Urbana      16735
# 13     2010.0          Branca                 Rural       6252
# 14     2010.0           Preta                Urbana       2665
# 15     2010.0           Preta                 Rural        938
# 16     2010.0         Amarela                Urbana        790
# 17     2010.0         Amarela                 Rural        186
# 18     2010.0           Parda                Urbana      30783
# 19     2010.0           Parda                 Rural      11985
# 20     2010.0        Indígena                Urbana        124
# 21     2010.0        Indígena                 Rural        753
# 22     2010.0  Sem declaração                Urbana          5
# 23     2010.0  Sem declaração                 Rural          -
# 24     2010.0          Branca                Urbana      17809
# 25     2010.0          Branca                 Rural       7160
# 26     2010.0           Preta                Urbana       3312
# 27     2010.0           Preta                 Rural       1171
# 28     2010.0         Amarela                Urbana        777
# 29     2010.0         Amarela                 Rural        195
# ...       ...             ...                   ...        ...
# 57654  2010.0           Parda                Urbana         12
# 57655  2010.0           Parda                 Rural          1
# 57656  2010.0        Indígena                Urbana          -
# 57657  2010.0        Indígena                 Rural          -
# 57658  2010.0  Sem declaração                Urbana          -
# 57659  2010.0  Sem declaração                 Rural          -
# 57660  2010.0          Branca                Urbana         65
# 57661  2010.0          Branca                 Rural          2
# 57662  2010.0           Preta                Urbana         10
# 57663  2010.0           Preta                 Rural          -
# 57664  2010.0         Amarela                Urbana          3
# 57665  2010.0         Amarela                 Rural          -
# 57666  2010.0           Parda                Urbana         47
# 57667  2010.0           Parda                 Rural          3
# 57668  2010.0        Indígena                Urbana          1
# 57669  2010.0        Indígena                 Rural          -
# 57670  2010.0  Sem declaração                Urbana          -
# 57671  2010.0  Sem declaração                 Rural          -
# 57672     NaN             NaN                   NaN        NaN
# 57673     NaN             NaN                   NaN        NaN
# 57674     NaN             NaN                   NaN        NaN
# 57675     NaN             NaN                   NaN        NaN
# 57676     NaN             NaN                   NaN        NaN
# 57677     NaN             NaN                   NaN        NaN
# 57678     NaN             NaN                   NaN        NaN
# 57679     NaN             NaN                   NaN        NaN
# 57680     NaN             NaN                   NaN        NaN
# 57681     NaN             NaN                   NaN        NaN
# 57682     NaN             NaN                   NaN        NaN
# 57683     NaN             NaN                   NaN        NaN
#
# [57684 rows x 7 columns]

# %%
populacao = populacao[:57672]

# %%
populacao.columns
# Out:
# Index(['Unidade da Federação', 'Sexo', 'Idade', 'Ano', 'Cor ou raça',
#        'Situação do domicílio', 'Unnamed: 6'],
#       dtype='object')

# %%
populacao.rename(columns={'Unnamed: 6': "Quantidade", 'Unidade da Federação': "Estado"}, inplace=True)

# %%
populacao[:5]
# Out:
#   Unidade da Federação    Sexo       Idade     Ano Cor ou raça  \
# 0             Rondônia  Homens  0 a 4 anos  2010.0      Branca
# 1             Rondônia  Homens  0 a 4 anos  2010.0      Branca
# 2             Rondônia  Homens  0 a 4 anos  2010.0       Preta
# 3             Rondônia  Homens  0 a 4 anos  2010.0       Preta
# 4             Rondônia  Homens  0 a 4 anos  2010.0     Amarela
#
#   Situação do domicílio  Quantidade
# 0                Urbana       18720
# 1                 Rural        6024
# 2                Urbana        1755
# 3                 Rural         580
# 4                Urbana         643

# %%
populacao = populacao.replace('-', 0)

# %%
populacao['Quantidade'] = pd.to_numeric(populacao['Quantidade'])
populacao['Ano'] = pd.to_datetime(populacao['Ano'])

# %%
populacao.dtypes
# Out:
# Estado                    object
# Sexo                      object
# Idade                     object
# Ano                      float64
# Cor ou raça               object
# Situação do domicílio     object
# Quantidade                 int64
# dtype: object

# %%
populacao.groupby('Sexo').sum()
# Out:
#                  Ano  Quantidade
# Sexo
# Homens    57960360.0    93406990
# Mulheres  57960360.0    97348809

# %%
populacao.groupby(['Sexo', 'Cor ou raça']).sum()
# Out:
#                                Ano  Quantidade
# Sexo     Cor ou raça
# Homens   Amarela         9660060.0      951404
#          Branca          9660060.0    43652488
#          Indígena        9660060.0      409907
#          Parda           9660060.0    40861864
#          Preta           9660060.0     7526611
#          Sem declaração  9660060.0        4716
# Mulheres Amarela         9660060.0     1132884
#          Branca          9660060.0    47399158
#          Indígena        9660060.0      408056
#          Parda           9660060.0    41415469
#          Preta           9660060.0     6991350
#          Sem declaração  9660060.0        1892
