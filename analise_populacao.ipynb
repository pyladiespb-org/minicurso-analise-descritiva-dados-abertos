# %% [markdown]
# # Análise da população
#
# Fonte https://sidra.ibge.gov.br/tabela/3175

# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
populacao = pd.read_csv('.dpopulacao_genero_cor_2010.csv', delimiter=';', header=2)
populacao
# Out:
#                   Unidade da Federação  \
# 0                             Rondônia
# 1                             Rondônia
# 2                             Rondônia
# 3                             Rondônia
# 4                             Rondônia
# 5                             Rondônia
# 6                             Rondônia
# 7                             Rondônia
# 8                             Rondônia
# 9                             Rondônia
# 10                            Rondônia
# 11                            Rondônia
# 12                            Rondônia
# 13                            Rondônia
# 14                            Rondônia
# 15                            Rondônia
# 16                            Rondônia
# 17                            Rondônia
# 18                            Rondônia
# 19                            Rondônia
# 20                            Rondônia
# 21                            Rondônia
# 22                            Rondônia
# ...

# %%
populacao.shape
# Out:
# (57684, 7)

# %%
populacao = populacao[:57672]

# %%
populacao.columns
# Out:
# Index(['Unidade da Federação', 'Sexo', 'Idade', 'Ano', 'Cor ou raça',
#        'Situação do domicílio', 'Unnamed: 6'],
#       dtype='object')

# %%
populacao.columns = ['Unidade da Federação', 'Sexo', 'Idade', 'Ano', 'Cor ou raça',
       'Situação do domicílio', 'Quantidade']

# %%
populacao.columns
# Out:
# Index(['Unidade da Federação', 'Sexo', 'Idade', 'Ano', 'Cor ou raça',
#        'Situação do domicílio', 'Quantidade'],
#       dtype='object')

# %%
populacao
# Out:
#       Unidade da Federação      Sexo             Idade     Ano  \
# 0                 Rondônia    Homens        0 a 4 anos  2010.0
# 1                 Rondônia    Homens        0 a 4 anos  2010.0
# 2                 Rondônia    Homens        0 a 4 anos  2010.0
# 3                 Rondônia    Homens        0 a 4 anos  2010.0
# 4                 Rondônia    Homens        0 a 4 anos  2010.0
# 5                 Rondônia    Homens        0 a 4 anos  2010.0
# 6                 Rondônia    Homens        0 a 4 anos  2010.0
# 7                 Rondônia    Homens        0 a 4 anos  2010.0
# 8                 Rondônia    Homens        0 a 4 anos  2010.0
# 9                 Rondônia    Homens        0 a 4 anos  2010.0
# 10                Rondônia    Homens        0 a 4 anos  2010.0
# 11                Rondônia    Homens        0 a 4 anos  2010.0
# 12                Rondônia    Homens        5 a 9 anos  2010.0
# 13                Rondônia    Homens        5 a 9 anos  2010.0
# ...

# %%
populacao.
